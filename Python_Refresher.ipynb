# %% [markdown]
# <a href="https://colab.research.google.com/github/Godwill-Junior/Machine-Learning-with-Python-Bootcamp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Text: Variable

# %%
#create a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the baskets
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change tomato price

# %%
tomato_price = 100
print(tomato_price)
# Out:
# 100

# %% [markdown]
# Variable (ML Anchor)

# %%
# --- THE CLUES (Features group as X) ---
rainfall_mm = 4.25      # clue 1
bags_available = 100    # clue 2

# --- THE GOAL (target labeled as y) ---
predicted_price = 3200    # What our AI calculates

print("Inputs (x):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (x): 4.25 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# undstanding print

# %%
Liberia = 1847
print("Liberia")
print(Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# Data Type

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity))
print(type(price))
print(type(item_name))
print(type(stall_is_open))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
