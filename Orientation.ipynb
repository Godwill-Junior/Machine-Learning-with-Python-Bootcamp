# %% [markdown]
# <a href="https://colab.research.google.com/github/Godwill-Junior/Machine-Learning-with-Python-Bootcamp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of string

# %%
Greetings="What up doctor"
print(Greetings)
# Out:
# What up doctor

# %% [markdown]
# Example of Addition

# %%
A = 2
B = 3
C = A+B
print(C)

#Addition
# Out:
# 5
